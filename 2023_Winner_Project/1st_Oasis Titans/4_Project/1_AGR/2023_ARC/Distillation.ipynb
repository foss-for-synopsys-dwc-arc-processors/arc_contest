# %% [markdown]
# # <font color = purple> 2023 Synopsys ARC AIoT Design Contest - Knowledge Distillation </font>

# %% [markdown]
# # Knowledge Distillation & Model Fractionation

# %%
import os
import glob
import time
import matplotlib.pyplot as plt
import matplotlib.image as img
import numpy as np
import pandas as pd
from PIL import Image
from sklearn.model_selection import train_test_split

import tensorflow as tf
import tensorflow.keras as keras
from tensorflow.keras import Model
from tensorflow.keras.models import Sequential
from tensorflow.keras import layers

from tensorflow.keras.layers import Input
from tensorflow.keras.layers import Conv2D, DepthwiseConv2D
from tensorflow.keras.layers import MaxPooling2D, AveragePooling2D, GlobalAveragePooling2D
from tensorflow.keras.layers import UpSampling2D
from tensorflow.keras.layers import Activation, Softmax, ReLU
from tensorflow.keras.layers import BatchNormalization
from tensorflow.keras.layers import Layer, Flatten, Dense, Dropout, add
from tensorflow.keras.utils import to_categorical
# Out:
# 2023-07-08 18:24:52.955175: I tensorflow/stream_executor/platform/default/dso_loader.cc:53] Successfully opened dynamic library libcudart.so.11.0

# %%
# !nvidia-smi
# Out:
# Sat Jul  8 18:24:54 2023
# +-----------------------------------------------------------------------------+
# | NVIDIA-SMI 525.125.06   Driver Version: 525.125.06   CUDA Version: 12.0     |
# |-------------------------------+----------------------+----------------------+
# | GPU  Name        Persistence-M| Bus-Id        Disp.A | Volatile Uncorr. ECC |
# | Fan  Temp  Perf  Pwr:Usage/Cap|         Memory-Usage | GPU-Util  Compute M. |
# |                               |                      |               MIG M. |
# |===============================+======================+======================|
# |   0  NVIDIA GeForce ...  Off  | 00000000:02:00.0 Off |                  N/A |
# | 31%   29C    P8     9W / 250W |      7MiB / 11264MiB |      0%      Default |
# |                               |                      |                  N/A |
# +-------------------------------+----------------------+----------------------+
# |   1  NVIDIA GeForce ...  Off  | 00000000:82:00.0 Off |                  N/A |
# | 34%   36C    P8     9W / 250W |      7MiB / 11264MiB |      0%      Default |
# |                               |                      |                  N/A |
# +-------------------------------+----------------------+----------------------+
# |   2  NVIDIA GeForce ...  Off  | 00000000:83:00.0 Off |                  N/A |
# |  0%   35C    P8     9W / 300W |      6MiB / 11264MiB |      0%      Default |
# |                               |                      |                  N/A |
# +-------------------------------+----------------------+----------------------+
#
# +-----------------------------------------------------------------------------+
# | Processes:                                                                  |
# |  GPU   GI   CI        PID   Type   Process name                  GPU Memory |
# |        ID   ID                                                   Usage      |
# |=============================================================================|
# |  No running processes found                                                 |
# +-----------------------------------------------------------------------------+

# %%
gpus = tf.config.experimental.list_physical_devices('GPU')

for gpu in gpus:
    print(gpu)
    tf.config.experimental.set_memory_growth(gpu, True)
# Out:
# PhysicalDevice(name='/physical_device:GPU:0', device_type='GPU')
# PhysicalDevice(name='/physical_device:GPU:1', device_type='GPU')
# PhysicalDevice(name='/physical_device:GPU:2', device_type='GPU')
# 2023-07-08 18:24:54.241103: I tensorflow/stream_executor/platform/default/dso_loader.cc:53] Successfully opened dynamic library libcuda.so.1
# 2023-07-08 18:24:54.354367: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1733] Found device 0 with properties:
# pciBusID: 0000:83:00.0 name: NVIDIA GeForce RTX 2080 Ti computeCapability: 7.5
# coreClock: 1.65GHz coreCount: 68 deviceMemorySize: 10.75GiB deviceMemoryBandwidth: 573.69GiB/s
# 2023-07-08 18:24:54.354779: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1733] Found device 1 with properties:
# pciBusID: 0000:02:00.0 name: NVIDIA GeForce GTX 1080 Ti computeCapability: 6.1
# coreClock: 1.582GHz coreCount: 28 deviceMemorySize: 10.91GiB deviceMemoryBandwidth: 451.17GiB/s
# 2023-07-08 18:24:54.355125: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1733] Found device 2 with properties:
# pciBusID: 0000:82:00.0 name: NVIDIA GeForce GTX 1080 Ti computeCapability: 6.1
# coreClock: 1.582GHz coreCount: 28 deviceMemorySize: 10.91GiB deviceMemoryBandwidth: 451.17GiB/s
# 2023-07-08 18:24:54.355177: I tensorflow/stream_executor/platform/default/dso_loader.cc:53] Successfully opened dynamic library libcudart.so.11.0
# 2023-07-08 18:24:54.363114: I tensorflow/stream_executor/platform/default/dso_loader.cc:53] Successfully opened dynamic library libcublas.so.11
# 2023-07-08 18:24:54.363197: I tensorflow/stream_executor/platform/default/dso_loader.cc:53] Successfully opened dynamic library libcublasLt.so.11
# 2023-07-08 18:24:54.410396: I tensorflow/stream_executor/platform/default/dso_loader.cc:53] Successfully opened dynamic library libcufft.so.10
# 2023-07-08 18:24:54.410871: I tensorflow/stream_executor/platform/default/dso_loader.cc:53] Successfully opened dynamic library libcurand.so.10
# 2023-07-08 18:24:54.412003: I tensorflow/stream_executor/platform/default/dso_loader.cc:53] Successfully opened dynamic library libcusolver.so.11
# 2023-07-08 18:24:54.413380: I tensorflow/stream_executor/platform/default/dso_loader.cc:53] Successfully opened dynamic library libcusparse.so.11
# 2023-07-08 18:24:54.413636: I tensorflow/stream_executor/platform/default/dso_loader.cc:53] Successfully opened dynamic library libcudnn.so.8
# 2023-07-08 18:24:54.415484: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1871] Adding visible gpu devices: 0, 1, 2

# %% [markdown]
# ## <font color = navy> Configurations </font>

# %%
class Config():
    # Data path
    IMAGE_DIR = "./train_img"
    LABEL_DIR = "./train_label/label.csv"
    
    # Degree unit
    DEG_UNIT = 5
    
    #  Dataloader parameters
    SPLIT = 0.2
    
    # Batch size
    BATCH_SIZE = 6 #16 #8
    
    # Image size
    IMG_HEIGHT = 224 #224
    IMG_WIDTH = 224 #224
    
    # Model parameters
    NUM_CLASSES = int(360 / DEG_UNIT)
    IN_CHANNEL = 1
    INPUT_SHAPE = (IMG_HEIGHT, IMG_WIDTH, IN_CHANNEL)
    
    # Learning parameters
    lr = 1e-3
    num_epochs = 30 # 20 #30
    teacher_loss_func = keras.losses.SparseCategoricalCrossentropy(from_logits=True)
    student_loss_func = keras.losses.SparseCategoricalCrossentropy(from_logits=True)
    distill_loss_func = keras.losses.KLDivergence()
    loss_func = "categorical_crossentropy"
    
    # Optimizer parameters
    opt = 'adam'
    
    # Distiller parameters
    alpha = 0.1      # weight to student_loss_fn and 1-alpha to distill_loss_func
    temperature = 3  # Temperature for softening probability distributions. Larger temperature gives softer distributions.
    
    # Model
    NUM_STAGE = 4
    model_names = ['MobileNetV2-base', 'MobileNetV2-small', 'MobileNetV2-tiny', 'MobileNetV2-micro']
    model_archs = ['base', 'small', 'tiny', 'micro']
    models = [None] * NUM_STAGE
    trainableParams = [None] * NUM_STAGE
    nonTrainableParams = [None] * NUM_STAGE
    totalParams = [None] * NUM_STAGE

# %% [markdown]
# ## <font color = navy> Load and Preprocess Dataset </font>

# %%
def load_data(img_path, lab_path, split=0.2):
    img_files = sorted(glob.glob(img_path + "/*"), key=os.path.getmtime) # Sort by time
    lab_df = pd.read_csv(lab_path)['class'].to_numpy() # Read label from csv
    data_x = []
    data_y = []
    
    # Concatenate images & labels
    for idx, img_file in enumerate(img_files):
        # image
        img = Image.open(img_file)
        img = img.convert('L') # Convert to gray
        img = np.array(img, dtype=int)
        img = img - 128.0 # Normalize
        
        # label
        lab = np.array(lab_df[idx], dtype=int)
        lab = np.expand_dims(lab, axis=0)
        
        data_x.append(img)
        data_y.append(lab)
    
    # Train & test split
    X_train, X_test, y_train, y_test = train_test_split(data_x, data_y, test_size=split, random_state=42, shuffle=True)
    
    X_train = np.array(X_train)
    y_train = np.array(y_train)
    
    X_test = np.array(X_test)
    y_test = np.array(y_test)

    return X_train, X_test, y_train, y_test

# %%
# Loading the dataset
X_train, X_test, y_train, y_test = load_data(Config.IMAGE_DIR, Config.LABEL_DIR)

# %% [markdown]
# ## <font color = navy> Show Data </font>

# %%
fig = plt.figure(figsize=(15,10))
for i in range(15):  
    ax = fig.add_subplot(3, 5, i+1)
    img = Image.fromarray(np.uint8(X_train[i] + 128)) # *255
    img = img.convert('RGBA')
    
    ax.imshow(img, cmap=plt.get_cmap('gray'))
    lab = np.squeeze(y_train[i])
    lower = lab * Config.DEG_UNIT
    upper = (lab+1) * Config.DEG_UNIT
    ax.set_title('degree: {y1}~{y2}'.format(y1=lower, y2=upper))
    plt.axis('off')

# %% [markdown]
# ## <font color = navy> One-hot encoding </font>

# %%
# y_train = to_categorical(y_train, Config.NUM_CLASSES)
# y_test = to_categorical(y_test, Config.NUM_CLASSES)

# %%
print("y_train: \n", y_train)
print("\n")
print("y_test: \n", y_test)
# Out:
# y_train:
#  [[25]
#  [47]
#  [24]
#  ...
#  [59]
#  [71]
#  [47]]
#
#
# y_test:
#  [[59]
#  [16]
#  [ 8]
#  ...
#  [47]
#  [18]
#  [29]]

# %% [markdown]
# ## <font color = navy> Reshape Images </font>

# %%
# Reshape
X_train = X_train.reshape(-1, Config.IMG_HEIGHT, Config.IMG_WIDTH, 1)
X_test = X_test.reshape(-1, Config.IMG_HEIGHT, Config.IMG_WIDTH, 1)

# %% [markdown]
# ## <font color = navy> Build Models </font>

# %% [markdown]
# ### <font color = red> Build Model: MobileNetV2 </font>

# %%
def expansion_block(x, t, filters, block_id):
    prefix = 'block_{}_'.format(block_id)
    total_filter = t*filters
    x = Conv2D(total_filter, 1, padding='same',use_bias=False, name=prefix+'expand')(x)
    x = BatchNormalization(name=prefix+'expand_bn')(x)
    x = ReLU(6, name=prefix+'expand_relu')(x) # ReLU 6
    
    return x

def depthwise_block(x, stride, block_id):
    prefix = 'block_{}_'.format(block_id)
    x = DepthwiseConv2D(3, strides=(stride,stride), padding='same', use_bias=False, name=prefix +'depthwise_conv')(x)
    x = BatchNormalization(name=prefix+'dw_bn')(x)
    x = ReLU(6,name=prefix+'dw_relu')(x)
    
    return x

def projection_block(x, out_channels, block_id):
    prefix = 'block_{}_'.format(block_id)
    x = Conv2D(filters=out_channels, kernel_size=1, padding='same', use_bias=False, name=prefix+'compress')(x)
    x = BatchNormalization(name=prefix+'compress_bn')(x)
    
    return x

# %%
def Bottleneck(x, t, filters, out_channels, stride, block_id):
    y = expansion_block(x, t, filters, block_id)
    y = depthwise_block(y, stride, block_id)
    y = projection_block(y, out_channels, block_id)
    
    if y.shape[-1]==x.shape[-1]:
        y = add([x,y])
    return y

# %%
def MobileNetV2(input_image=Config.INPUT_SHAPE, n_classes=Config.NUM_CLASSES, arch='base'):
    if arch == 'base':
        input = Input(input_image)

        x = Conv2D(32,kernel_size=3,strides=(2,2),padding = 'same', use_bias=False)(input)
        x = BatchNormalization(name='conv1_bn')(x)
        x = ReLU(6, name = 'conv1_relu')(x)

        # 17 Bottlenecks

        x = depthwise_block(x,stride=1,block_id=1)
        x = projection_block(x, out_channels=16,block_id=1)

        x = Bottleneck(x, t = 6, filters = x.shape[-1], out_channels = 24, stride = 2,block_id = 2)
        x = Bottleneck(x, t = 6, filters = x.shape[-1], out_channels = 24, stride = 1,block_id = 3)

        x = Bottleneck(x, t = 6, filters = x.shape[-1], out_channels = 32, stride = 2,block_id = 4)
        x = Bottleneck(x, t = 6, filters = x.shape[-1], out_channels = 32, stride = 1,block_id = 5)
        x = Bottleneck(x, t = 6, filters = x.shape[-1], out_channels = 32, stride = 1,block_id = 6)

        x = Bottleneck(x, t = 6, filters = x.shape[-1], out_channels = 64, stride = 2,block_id = 7)
        x = Bottleneck(x, t = 6, filters = x.shape[-1], out_channels = 64, stride = 1,block_id = 8)
        x = Bottleneck(x, t = 6, filters = x.shape[-1], out_channels = 64, stride = 1,block_id = 9)
        x = Bottleneck(x, t = 6, filters = x.shape[-1], out_channels = 64, stride = 1,block_id = 10)

        x = Bottleneck(x, t = 6, filters = x.shape[-1], out_channels = 96, stride = 1,block_id = 11)
        x = Bottleneck(x, t = 6, filters = x.shape[-1], out_channels = 96, stride = 1,block_id = 12)
        x = Bottleneck(x, t = 6, filters = x.shape[-1], out_channels = 96, stride = 1,block_id = 13)

        x = Bottleneck(x, t = 6, filters = x.shape[-1], out_channels = 160, stride = 2,block_id = 14)
        x = Bottleneck(x, t = 6, filters = x.shape[-1], out_channels = 160, stride = 1,block_id = 15)
        x = Bottleneck(x, t = 6, filters = x.shape[-1], out_channels = 160, stride = 1,block_id = 16)

        x = Bottleneck(x, t = 6, filters = x.shape[-1], out_channels = 320, stride = 1,block_id = 17)


        #1*1 conv
        x = Conv2D(filters = 1280, kernel_size = 1, padding='same', use_bias=False, name = 'last_conv')(x)
        x = BatchNormalization(name='last_bn')(x)
        x = ReLU(6,name='last_relu')(x)

        #AvgPool 7*7
        x = GlobalAveragePooling2D(name='global_average_pool')(x)

        output = Dense(n_classes, activation='softmax')(x)

        model = Model(input, output)

        return model
    
    
    elif arch == 'small':
        input = Input(input_image)

        x = Conv2D(16,kernel_size=3,strides=(2,2),padding = 'same', use_bias=False)(input)
        x = BatchNormalization(name='conv1_bn')(x)
        x = ReLU(6, name = 'conv1_relu')(x)

        # 17 Bottlenecks

        x = depthwise_block(x,stride=1,block_id=1)
        x = projection_block(x, out_channels=8,block_id=1)

        x = Bottleneck(x, t = 6, filters = x.shape[-1], out_channels = 12, stride = 2,block_id = 2)
        x = Bottleneck(x, t = 6, filters = x.shape[-1], out_channels = 12, stride = 1,block_id = 3)

        x = Bottleneck(x, t = 6, filters = x.shape[-1], out_channels = 16, stride = 2,block_id = 4)
        x = Bottleneck(x, t = 6, filters = x.shape[-1], out_channels = 16, stride = 1,block_id = 5)
        x = Bottleneck(x, t = 6, filters = x.shape[-1], out_channels = 16, stride = 1,block_id = 6)

        x = Bottleneck(x, t = 6, filters = x.shape[-1], out_channels = 32, stride = 2,block_id = 7)
        x = Bottleneck(x, t = 6, filters = x.shape[-1], out_channels = 32, stride = 1,block_id = 8)
        x = Bottleneck(x, t = 6, filters = x.shape[-1], out_channels = 32, stride = 1,block_id = 9)
        x = Bottleneck(x, t = 6, filters = x.shape[-1], out_channels = 32, stride = 1,block_id = 10)

        x = Bottleneck(x, t = 6, filters = x.shape[-1], out_channels = 48, stride = 1,block_id = 11)
        x = Bottleneck(x, t = 6, filters = x.shape[-1], out_channels = 48, stride = 1,block_id = 12)
        x = Bottleneck(x, t = 6, filters = x.shape[-1], out_channels = 48, stride = 1,block_id = 13)

        x = Bottleneck(x, t = 6, filters = x.shape[-1], out_channels = 80, stride = 2,block_id = 14)
        x = Bottleneck(x, t = 6, filters = x.shape[-1], out_channels = 80, stride = 1,block_id = 15)
        x = Bottleneck(x, t = 6, filters = x.shape[-1], out_channels = 80, stride = 1,block_id = 16)

        x = Bottleneck(x, t = 6, filters = x.shape[-1], out_channels = 160, stride = 1,block_id = 17)


        #1*1 conv
        x = Conv2D(filters = 640, kernel_size = 1, padding='same', use_bias=False, name = 'last_conv')(x)
        x = BatchNormalization(name='last_bn')(x)
        x = ReLU(6,name='last_relu')(x)

        #AvgPool 7*7
        x = GlobalAveragePooling2D(name='global_average_pool')(x)

        output = Dense(n_classes, activation='softmax')(x)

        model = Model(input, output)

        return model
    
    
    elif arch == 'tiny':
        input = Input(input_image)

        x = Conv2D(8,kernel_size=3,strides=(2,2),padding = 'same', use_bias=False)(input)
        x = BatchNormalization(name='conv1_bn')(x)
        x = ReLU(6, name = 'conv1_relu')(x)

        # 17 Bottlenecks

        x = depthwise_block(x,stride=1,block_id=1)
        x = projection_block(x, out_channels=4,block_id=1)

        x = Bottleneck(x, t = 6, filters = x.shape[-1], out_channels = 6, stride = 2,block_id = 2)
        x = Bottleneck(x, t = 6, filters = x.shape[-1], out_channels = 6, stride = 1,block_id = 3)

        x = Bottleneck(x, t = 6, filters = x.shape[-1], out_channels = 8, stride = 2,block_id = 4)
        x = Bottleneck(x, t = 6, filters = x.shape[-1], out_channels = 8, stride = 1,block_id = 5)
        x = Bottleneck(x, t = 6, filters = x.shape[-1], out_channels = 8, stride = 1,block_id = 6)

        x = Bottleneck(x, t = 6, filters = x.shape[-1], out_channels = 16, stride = 2,block_id = 7)
        x = Bottleneck(x, t = 6, filters = x.shape[-1], out_channels = 16, stride = 1,block_id = 8)
        x = Bottleneck(x, t = 6, filters = x.shape[-1], out_channels = 16, stride = 1,block_id = 9)
        x = Bottleneck(x, t = 6, filters = x.shape[-1], out_channels = 16, stride = 1,block_id = 10)

        x = Bottleneck(x, t = 6, filters = x.shape[-1], out_channels = 24, stride = 1,block_id = 11)
        x = Bottleneck(x, t = 6, filters = x.shape[-1], out_channels = 24, stride = 1,block_id = 12)
        x = Bottleneck(x, t = 6, filters = x.shape[-1], out_channels = 24, stride = 1,block_id = 13)

        x = Bottleneck(x, t = 6, filters = x.shape[-1], out_channels = 40, stride = 2,block_id = 14)
        x = Bottleneck(x, t = 6, filters = x.shape[-1], out_channels = 40, stride = 1,block_id = 15)
        x = Bottleneck(x, t = 6, filters = x.shape[-1], out_channels = 40, stride = 1,block_id = 16)

        x = Bottleneck(x, t = 6, filters = x.shape[-1], out_channels = 80, stride = 1,block_id = 17)


        #1*1 conv
        x = Conv2D(filters = 320, kernel_size = 1, padding='same', use_bias=False, name = 'last_conv')(x)
        x = BatchNormalization(name='last_bn')(x)
        x = ReLU(6,name='last_relu')(x)

        #AvgPool 7*7
        x = GlobalAveragePooling2D(name='global_average_pool')(x)

        output = Dense(n_classes, activation='softmax')(x)

        model = Model(input, output)

        return model
    
    
    elif arch == 'micro':
        input = Input(input_image)

        x = Conv2D(4,kernel_size=3,strides=(2,2),padding = 'same', use_bias=False)(input)
        x = BatchNormalization(name='conv1_bn')(x)
        x = ReLU(6, name = 'conv1_relu')(x)

        # 17 Bottlenecks

        x = depthwise_block(x,stride=1,block_id=1)
        x = projection_block(x, out_channels=4,block_id=1)

        x = Bottleneck(x, t = 6, filters = x.shape[-1], out_channels = 3, stride = 2,block_id = 2)
        x = Bottleneck(x, t = 6, filters = x.shape[-1], out_channels = 3, stride = 1,block_id = 3)

        x = Bottleneck(x, t = 6, filters = x.shape[-1], out_channels = 4, stride = 2,block_id = 4)
        x = Bottleneck(x, t = 6, filters = x.shape[-1], out_channels = 4, stride = 1,block_id = 5)
        x = Bottleneck(x, t = 6, filters = x.shape[-1], out_channels = 4, stride = 1,block_id = 6)

        x = Bottleneck(x, t = 6, filters = x.shape[-1], out_channels = 8, stride = 2,block_id = 7)
        x = Bottleneck(x, t = 6, filters = x.shape[-1], out_channels = 8, stride = 1,block_id = 8)
        x = Bottleneck(x, t = 6, filters = x.shape[-1], out_channels = 8, stride = 1,block_id = 9)
        x = Bottleneck(x, t = 6, filters = x.shape[-1], out_channels = 8, stride = 1,block_id = 10)

        x = Bottleneck(x, t = 6, filters = x.shape[-1], out_channels = 12, stride = 1,block_id = 11)
        x = Bottleneck(x, t = 6, filters = x.shape[-1], out_channels = 12, stride = 1,block_id = 12)
        x = Bottleneck(x, t = 6, filters = x.shape[-1], out_channels = 12, stride = 1,block_id = 13)

        x = Bottleneck(x, t = 6, filters = x.shape[-1], out_channels = 20, stride = 2,block_id = 14)
        x = Bottleneck(x, t = 6, filters = x.shape[-1], out_channels = 20, stride = 1,block_id = 15)
        x = Bottleneck(x, t = 6, filters = x.shape[-1], out_channels = 20, stride = 1,block_id = 16)

        x = Bottleneck(x, t = 6, filters = x.shape[-1], out_channels = 40, stride = 1,block_id = 17)


        #1*1 conv
        x = Conv2D(filters = 160 , kernel_size = 1, padding='same', use_bias=False, name = 'last_conv')(x)
        x = BatchNormalization(name='last_bn')(x)
        x = ReLU(6,name='last_relu')(x)

        #AvgPool 7*7
        x = GlobalAveragePooling2D(name='global_average_pool')(x)

        output = Dense(n_classes, activation='softmax')(x)

        model = Model(input, output)

        return model

# %%
for i in range(Config.NUM_STAGE):
    print('[' + Config.model_names[i] + ']')
    Config.models[i] = MobileNetV2(arch=Config.model_archs[i])
    Config.trainableParams[i] = np.sum([np.prod(v.get_shape()) for v in Config.models[i].trainable_weights])
    Config.nonTrainableParams[i] = np.sum([np.prod(v.get_shape()) for v in Config.models[i].non_trainable_weights])
    Config.totalParams[i] = Config.trainableParams[i] + Config.nonTrainableParams[i]
    print('Trainable Prameters: ', Config.trainableParams[i])
    print('Non-trainable Parameters: ', Config.nonTrainableParams[i])
    print('Total Parameters: ', Config.totalParams[i])
    # Config.models[i].summary()
    print('-------------------------------------------------')
# Out:
# [MobileNetV2-base]
# 2023-07-08 18:25:11.387212: I tensorflow/core/platform/cpu_feature_guard.cc:142] This TensorFlow binary is optimized with oneAPI Deep Neural Network Library (oneDNN) to use the following CPU instructions in performance-critical operations:  AVX2 FMA
# To enable them in other operations, rebuild TensorFlow with the appropriate compiler flags.
# 2023-07-08 18:25:11.990769: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1733] Found device 0 with properties:
# pciBusID: 0000:83:00.0 name: NVIDIA GeForce RTX 2080 Ti computeCapability: 7.5
# coreClock: 1.65GHz coreCount: 68 deviceMemorySize: 10.75GiB deviceMemoryBandwidth: 573.69GiB/s
# 2023-07-08 18:25:11.991038: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1733] Found device 1 with properties:
# pciBusID: 0000:02:00.0 name: NVIDIA GeForce GTX 1080 Ti computeCapability: 6.1
# coreClock: 1.582GHz coreCount: 28 deviceMemorySize: 10.91GiB deviceMemoryBandwidth: 451.17GiB/s
# 2023-07-08 18:25:11.991278: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1733] Found device 2 with properties:
# pciBusID: 0000:82:00.0 name: NVIDIA GeForce GTX 1080 Ti computeCapability: 6.1
# coreClock: 1.582GHz coreCount: 28 deviceMemorySize: 10.91GiB deviceMemoryBandwidth: 451.17GiB/s
# 2023-07-08 18:25:11.992589: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1871] Adding visible gpu devices: 0, 1, 2
# 2023-07-08 18:25:11.992669: I tensorflow/stream_executor/platform/default/dso_loader.cc:53] Successfully opened dynamic library libcudart.so.11.0
# 2023-07-08 18:25:12.984603: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1258] Device interconnect StreamExecutor with strength 1 edge matrix:
# 2023-07-08 18:25:12.984645: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1264]      0 1 2
# 2023-07-08 18:25:12.984654: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1277] 0:   N N N
# 2023-07-08 18:25:12.984659: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1277] 1:   N N N
# 2023-07-08 18:25:12.984663: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1277] 2:   N N N
# 2023-07-08 18:25:12.987433: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1418] Created TensorFlow device (/job:localhost/replica:0/task:0/device:GPU:0 with 9644 MB memory) -> physical GPU (device: 0, name: NVIDIA GeForce RTX 2080 Ti, pci bus id: 0000:83:00.0, compute capability: 7.5)
# 2023-07-08 18:25:12.988157: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1418] Created TensorFlow device (/job:localhost/replica:0/task:0/device:GPU:1 with 10405 MB memory) -> physical GPU (device: 1, name: NVIDIA GeForce GTX 1080 Ti, pci bus id: 0000:02:00.0, compute capability: 6.1)
# 2023-07-08 18:25:12.988809: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1418] Created TensorFlow device (/job:localhost/replica:0/task:0/device:GPU:2 with 10405 MB memory) -> physical GPU (device: 2, name: NVIDIA GeForce GTX 1080 Ti, pci bus id: 0000:82:00.0, compute capability: 6.1)
# Trainable Prameters:  2315528
# Non-trainable Parameters:  34112
# Total Parameters:  2349640
# -------------------------------------------------
# [MobileNetV2-small]
# Trainable Prameters:  626632
# Non-trainable Parameters:  17056
# Total Parameters:  643688
# -------------------------------------------------
# [MobileNetV2-tiny]
# Trainable Prameters:  180560
# Non-trainable Parameters:  8528
# Total Parameters:  189088
# -------------------------------------------------
# [MobileNetV2-micro]
# Trainable Prameters:  57394
# Non-trainable Parameters:  4316
# Total Parameters:  61710
# -------------------------------------------------

# %% [markdown]
# ## <font color = navy> Distiller </font>

# %%
class Distiller(keras.Model):
    def __init__(self, student, teacher):
        super().__init__()
        self.teacher = teacher
        self.student = student

    def compile(
        self,
        optimizer,
        metrics,
        student_loss_fn,
        distillation_loss_fn,
        alpha=0.1,
        temperature=3,
    ):
        """ Configure the distiller.

        Args:
            optimizer: Keras optimizer for the student weights
            metrics: Keras metrics for evaluation
            student_loss_fn: Loss function of difference between student
                predictions and ground-truth
            distillation_loss_fn: Loss function of difference between soft
                student predictions and soft teacher predictions
            alpha: weight to student_loss_fn and 1-alpha to distillation_loss_fn
            temperature: Temperature for softening probability distributions.
                Larger temperature gives softer distributions.
        """
        super().compile(optimizer=optimizer, metrics=metrics)
        self.student_loss_fn = student_loss_fn
        self.distillation_loss_fn = distillation_loss_fn
        self.alpha = alpha
        self.temperature = temperature

    def train_step(self, data):
        # Unpack data
        x, y = data

        # Forward pass of teacher
        teacher_predictions = self.teacher(x, training=False)

        with tf.GradientTape() as tape:
            # Forward pass of student
            student_predictions = self.student(x, training=True)

            # Compute losses
            student_loss = self.student_loss_fn(y, student_predictions)

            # Compute scaled distillation loss from https://arxiv.org/abs/1503.02531
            # The magnitudes of the gradients produced by the soft targets scale
            # as 1/T^2, multiply them by T^2 when using both hard and soft targets.
            distillation_loss = (
                self.distillation_loss_fn(
                    tf.nn.softmax(teacher_predictions / self.temperature, axis=1),
                    tf.nn.softmax(student_predictions / self.temperature, axis=1),
                )
                * self.temperature**2
            )

            loss = self.alpha * student_loss + (1 - self.alpha) * distillation_loss

        # Compute gradients
        trainable_vars = self.student.trainable_variables
        gradients = tape.gradient(loss, trainable_vars)

        # Update weights
        self.optimizer.apply_gradients(zip(gradients, trainable_vars))

        # Update the metrics configured in `compile()`.
        self.compiled_metrics.update_state(y, student_predictions)

        # Return a dict of performance
        results = {m.name: m.result() for m in self.metrics}
        results.update(
            {"student_loss": student_loss, "distillation_loss": distillation_loss}
        )
        return results

    def test_step(self, data):
        # Unpack the data
        x, y = data

        # Compute predictions
        y_prediction = self.student(x, training=False)

        # Calculate the loss
        student_loss = self.student_loss_fn(y, y_prediction)

        # Update the metrics.
        self.compiled_metrics.update_state(y, y_prediction)

        # Return a dict of performance
        results = {m.name: m.result() for m in self.metrics}
        results.update({"student_loss": student_loss})
        return results

# %% [markdown]
# ## <font color = navy> Create Teacher Model </font>

# %%
teacher = Config.models[0]

# %%
teacher.compile(
    optimizer=Config.opt,
    loss=Config.teacher_loss_func,
    metrics=[keras.metrics.SparseCategoricalAccuracy()]
)

# %% [markdown]
# ## <font color = navy> Create Student Model </font>

# %%
student = Config.models[3]

# %%
student.compile(
    optimizer=Config.opt,
    loss=Config.teacher_loss_func,
    metrics=[keras.metrics.SparseCategoricalAccuracy()]
)

# %% [markdown]
# ## <font color = navy> Save & Load for Copy Student Model </font>

# %%
student.save('student')
student = keras.models.load_model("student")
copy_student = keras.models.load_model("student")
# Out:
# 2023-07-08 18:25:24.248400: W tensorflow/python/util/util.cc:348] Sets are not currently considered sequences, but this may change in the future, so consider avoiding using them.
# /home/bakerchen/.conda/envs/2023ARC/lib/python3.8/site-packages/tensorflow/python/keras/utils/generic_utils.py:494: CustomMaskWarning: Custom mask layers require a config and must override get_config. When loading, the custom mask layer must be passed to the custom_objects argument.
#   warnings.warn('Custom mask layers require a config and must override '
# INFO:tensorflow:Assets written to: student/assets

# %%
# Clone student for later comparison
student_scratch = copy_student

# %% [markdown]
# ## <font color = navy> Train Teacher Model </font>

# %%
# Train and evaluate teacher on data.
teacher_history = teacher.fit(X_train, y_train,
                              validation_split=0.2,
                              batch_size=Config.BATCH_SIZE,
                              verbose=1,
                              epochs=Config.num_epochs)
# Out:
# 2023-07-08 18:25:49.707876: I tensorflow/compiler/mlir/mlir_graph_optimization_pass.cc:176] None of the MLIR Optimization Passes are enabled (registered 2)
# 2023-07-08 18:25:49.726794: I tensorflow/core/platform/profile_utils/cpu_utils.cc:114] CPU Frequency: 1999990000 Hz
# Epoch 1/30
# /home/bakerchen/.conda/envs/2023ARC/lib/python3.8/site-packages/tensorflow/python/keras/backend.py:4929: UserWarning: "`sparse_categorical_crossentropy` received `from_logits=True`, but the `output` argument was produced by a sigmoid or softmax activation and thus does not represent logits. Was this intended?"
#   warnings.warn(
# 2023-07-08 18:25:53.328612: I tensorflow/stream_executor/platform/default/dso_loader.cc:53] Successfully opened dynamic library libcudnn.so.8
# 2023-07-08 18:25:54.210834: I tensorflow/stream_executor/cuda/cuda_dnn.cc:359] Loaded cuDNN version 8700
# 2023-07-08 18:25:54.909074: E tensorflow/core/platform/default/subprocess.cc:304] Start cannot spawn child process: No such file or directory
# 2023-07-08 18:25:54.909121: W tensorflow/stream_executor/gpu/asm_compiler.cc:56] Couldn't invoke ptxas --version
# 2023-07-08 18:25:54.910286: E tensorflow/core/platform/default/subprocess.cc:304] Start cannot spawn child process: No such file or directory
# 2023-07-08 18:25:54.910385: W tensorflow/stream_executor/gpu/redzone_allocator.cc:314] Internal: Failed to launch ptxas
# Relying on driver to perform ptx compilation.
# Modify $PATH to customize ptxas location.
# This message will be only logged once.
# 2023-07-08 18:25:54.919315: I tensorflow/stream_executor/platform/default/dso_loader.cc:53] Successfully opened dynamic library libcublas.so.11
# 2023-07-08 18:25:54.919667: I tensorflow/stream_executor/platform/default/dso_loader.cc:53] Successfully opened dynamic library libcublasLt.so.11
# 1067/1067 [==============================] - 77s 66ms/step - loss: 4.3827 - sparse_categorical_accuracy: 0.0152 - val_loss: 4.3206 - val_sparse_categorical_accuracy: 0.0100
# Epoch 2/30
# 1067/1067 [==============================] - 69s 64ms/step - loss: 4.3022 - sparse_categorical_accuracy: 0.0122 - val_loss: 4.3014 - val_sparse_categorical_accuracy: 0.0137
# Epoch 3/30
# 1067/1067 [==============================] - 67s 62ms/step - loss: 4.2828 - sparse_categorical_accuracy: 0.0177 - val_loss: 4.1571 - val_sparse_categorical_accuracy: 0.0188
# Epoch 4/30
# 1067/1067 [==============================] - 67s 63ms/step - loss: 3.0472 - sparse_categorical_accuracy: 0.1078 - val_loss: 2.1854 - val_sparse_categorical_accuracy: 0.1725
# Epoch 5/30
# 1067/1067 [==============================] - 70s 65ms/step - loss: 2.1075 - sparse_categorical_accuracy: 0.2138 - val_loss: 1.7125 - val_sparse_categorical_accuracy: 0.3300
# Epoch 6/30
# 1067/1067 [==============================] - 69s 65ms/step - loss: 1.6048 - sparse_categorical_accuracy: 0.3666 - val_loss: 1.1242 - val_sparse_categorical_accuracy: 0.5487
# Epoch 7/30
# 1067/1067 [==============================] - 69s 65ms/step - loss: 1.1826 - sparse_categorical_accuracy: 0.5150 - val_loss: 0.8526 - val_sparse_categorical_accuracy: 0.6513
# Epoch 8/30
# 1067/1067 [==============================] - 69s 65ms/step - loss: 0.9122 - sparse_categorical_accuracy: 0.6105 - val_loss: 0.8360 - val_sparse_categorical_accuracy: 0.6475
# Epoch 9/30
# 1067/1067 [==============================] - 68s 64ms/step - loss: 0.7968 - sparse_categorical_accuracy: 0.6559 - val_loss: 0.7394 - val_sparse_categorical_accuracy: 0.6725
# Epoch 10/30
# 1067/1067 [==============================] - 69s 65ms/step - loss: 0.7248 - sparse_categorical_accuracy: 0.6933 - val_loss: 0.6084 - val_sparse_categorical_accuracy: 0.7469
# Epoch 11/30
# 1067/1067 [==============================] - 69s 65ms/step - loss: 0.6784 - sparse_categorical_accuracy: 0.7064 - val_loss: 0.5794 - val_sparse_categorical_accuracy: 0.7613
# Epoch 12/30
# 1067/1067 [==============================] - 69s 65ms/step - loss: 0.6127 - sparse_categorical_accuracy: 0.7364 - val_loss: 0.5629 - val_sparse_categorical_accuracy: 0.7588
# Epoch 13/30
# 1067/1067 [==============================] - 70s 66ms/step - loss: 0.5876 - sparse_categorical_accuracy: 0.7456 - val_loss: 0.8368 - val_sparse_categorical_accuracy: 0.6631
# Epoch 14/30
# 1067/1067 [==============================] - 70s 65ms/step - loss: 0.5495 - sparse_categorical_accuracy: 0.7731 - val_loss: 0.5904 - val_sparse_categorical_accuracy: 0.7550
# Epoch 15/30
# 1067/1067 [==============================] - 70s 65ms/step - loss: 0.5254 - sparse_categorical_accuracy: 0.7789 - val_loss: 0.6541 - val_sparse_categorical_accuracy: 0.7487
# Epoch 16/30
# 1067/1067 [==============================] - 68s 64ms/step - loss: 0.4842 - sparse_categorical_accuracy: 0.7945 - val_loss: 0.4976 - val_sparse_categorical_accuracy: 0.7894
# Epoch 17/30
# 1067/1067 [==============================] - 69s 65ms/step - loss: 0.4688 - sparse_categorical_accuracy: 0.8069 - val_loss: 0.4897 - val_sparse_categorical_accuracy: 0.7919
# Epoch 18/30
# 1067/1067 [==============================] - 69s 65ms/step - loss: 0.4608 - sparse_categorical_accuracy: 0.8123 - val_loss: 0.3905 - val_sparse_categorical_accuracy: 0.8244
# Epoch 19/30
# 1067/1067 [==============================] - 69s 65ms/step - loss: 0.4382 - sparse_categorical_accuracy: 0.8192 - val_loss: 0.4463 - val_sparse_categorical_accuracy: 0.8025
# Epoch 20/30
# 1067/1067 [==============================] - 69s 65ms/step - loss: 0.4088 - sparse_categorical_accuracy: 0.8314 - val_loss: 0.4726 - val_sparse_categorical_accuracy: 0.7950
# Epoch 21/30
# 1067/1067 [==============================] - 69s 64ms/step - loss: 0.3992 - sparse_categorical_accuracy: 0.8372 - val_loss: 0.4138 - val_sparse_categorical_accuracy: 0.8238
# Epoch 22/30
# 1067/1067 [==============================] - 69s 65ms/step - loss: 0.3804 - sparse_categorical_accuracy: 0.8483 - val_loss: 0.4073 - val_sparse_categorical_accuracy: 0.8256
# Epoch 23/30
# 1067/1067 [==============================] - 69s 65ms/step - loss: 0.3664 - sparse_categorical_accuracy: 0.8516 - val_loss: 0.3367 - val_sparse_categorical_accuracy: 0.8587
# Epoch 24/30
# 1067/1067 [==============================] - 69s 64ms/step - loss: 0.3503 - sparse_categorical_accuracy: 0.8570 - val_loss: 0.4945 - val_sparse_categorical_accuracy: 0.8062
# Epoch 25/30
# 1067/1067 [==============================] - 70s 65ms/step - loss: 0.3473 - sparse_categorical_accuracy: 0.8572 - val_loss: 0.4453 - val_sparse_categorical_accuracy: 0.8087
# Epoch 26/30
# 1067/1067 [==============================] - 68s 64ms/step - loss: 0.3408 - sparse_categorical_accuracy: 0.8612 - val_loss: 0.3974 - val_sparse_categorical_accuracy: 0.8369
# Epoch 27/30
# 1067/1067 [==============================] - 69s 64ms/step - loss: 0.3057 - sparse_categorical_accuracy: 0.8806 - val_loss: 0.3541 - val_sparse_categorical_accuracy: 0.8544
# Epoch 28/30
# 1067/1067 [==============================] - 69s 64ms/step - loss: 0.3033 - sparse_categorical_accuracy: 0.8753 - val_loss: 0.3219 - val_sparse_categorical_accuracy: 0.8694
# Epoch 29/30
# 1067/1067 [==============================] - 67s 63ms/step - loss: 0.2842 - sparse_categorical_accuracy: 0.8839 - val_loss: 0.3588 - val_sparse_categorical_accuracy: 0.8494
# Epoch 30/30
# 1067/1067 [==============================] - 69s 65ms/step - loss: 0.2861 - sparse_categorical_accuracy: 0.8873 - val_loss: 0.4225 - val_sparse_categorical_accuracy: 0.8319

# %% [markdown]
# ### <font color = red> Evaluation: Teacher Model </font>

# %%
teacher_score = teacher.evaluate(X_test, y_test, verbose=0)
print(teacher_score)
# Out:
# [0.41944271326065063, 0.8295000195503235]

# %% [markdown]
# ## <font color = navy> Distill Teacher to Student </font>

# %%
# Initialize and compile distiller
distiller = Distiller(student=student, teacher=teacher)
distiller.compile(
    optimizer=Config.opt,
    metrics=[keras.metrics.SparseCategoricalAccuracy()],
    student_loss_fn=Config.student_loss_func,
    distillation_loss_fn=Config.distill_loss_func,
    alpha=Config.alpha,
    temperature=Config.temperature,
)

# %%
# Distill teacher to student
distiller_history = distiller.fit(
    X_train, y_train,
    validation_split=0.2,
    batch_size=Config.BATCH_SIZE,
    verbose=1,
    epochs=Config.num_epochs)
# Out:
# Epoch 1/30
# 1067/1067 [==============================] - 77s 67ms/step - sparse_categorical_accuracy: 0.0289 - student_loss: 4.0994 - distillation_loss: 0.0068 - val_sparse_categorical_accuracy: 0.0487 - val_student_loss: 3.4394
# Epoch 2/30
# 1067/1067 [==============================] - 71s 66ms/step - sparse_categorical_accuracy: 0.1114 - student_loss: 2.9753 - distillation_loss: 0.0064 - val_sparse_categorical_accuracy: 0.2113 - val_student_loss: 2.0617
# Epoch 3/30
# 1067/1067 [==============================] - 69s 65ms/step - sparse_categorical_accuracy: 0.1920 - student_loss: 2.3097 - distillation_loss: 0.0059 - val_sparse_categorical_accuracy: 0.2931 - val_student_loss: 1.4914
# Epoch 4/30
# 1067/1067 [==============================] - 71s 66ms/step - sparse_categorical_accuracy: 0.3016 - student_loss: 1.8758 - distillation_loss: 0.0053 - val_sparse_categorical_accuracy: 0.4550 - val_student_loss: 1.2604
# Epoch 5/30
# 1067/1067 [==============================] - 67s 63ms/step - sparse_categorical_accuracy: 0.4480 - student_loss: 1.4249 - distillation_loss: 0.0044 - val_sparse_categorical_accuracy: 0.5913 - val_student_loss: 0.8829
# Epoch 6/30
# 1067/1067 [==============================] - 70s 66ms/step - sparse_categorical_accuracy: 0.5264 - student_loss: 1.1450 - distillation_loss: 0.0038 - val_sparse_categorical_accuracy: 0.6094 - val_student_loss: 0.6878
# Epoch 7/30
# 1067/1067 [==============================] - 70s 66ms/step - sparse_categorical_accuracy: 0.5859 - student_loss: 0.9993 - distillation_loss: 0.0034 - val_sparse_categorical_accuracy: 0.5800 - val_student_loss: 0.3450
# Epoch 8/30
# 1067/1067 [==============================] - 71s 67ms/step - sparse_categorical_accuracy: 0.6016 - student_loss: 0.9289 - distillation_loss: 0.0032 - val_sparse_categorical_accuracy: 0.6631 - val_student_loss: 0.7944
# Epoch 9/30
# 1067/1067 [==============================] - 70s 66ms/step - sparse_categorical_accuracy: 0.6234 - student_loss: 0.8805 - distillation_loss: 0.0031 - val_sparse_categorical_accuracy: 0.7412 - val_student_loss: 0.8052
# Epoch 10/30
# 1067/1067 [==============================] - 70s 65ms/step - sparse_categorical_accuracy: 0.6616 - student_loss: 0.8048 - distillation_loss: 0.0029 - val_sparse_categorical_accuracy: 0.7494 - val_student_loss: 0.3569
# Epoch 11/30
# 1067/1067 [==============================] - 70s 66ms/step - sparse_categorical_accuracy: 0.6700 - student_loss: 0.7738 - distillation_loss: 0.0028 - val_sparse_categorical_accuracy: 0.7050 - val_student_loss: 0.4845
# Epoch 12/30
# 1067/1067 [==============================] - 69s 65ms/step - sparse_categorical_accuracy: 0.6994 - student_loss: 0.7269 - distillation_loss: 0.0027 - val_sparse_categorical_accuracy: 0.7738 - val_student_loss: 0.7205
# Epoch 13/30
# 1067/1067 [==============================] - 70s 66ms/step - sparse_categorical_accuracy: 0.7158 - student_loss: 0.6618 - distillation_loss: 0.0025 - val_sparse_categorical_accuracy: 0.7494 - val_student_loss: 0.5871
# Epoch 14/30
# 1067/1067 [==============================] - 68s 64ms/step - sparse_categorical_accuracy: 0.7223 - student_loss: 0.6564 - distillation_loss: 0.0025 - val_sparse_categorical_accuracy: 0.7437 - val_student_loss: 0.9440
# Epoch 15/30
# 1067/1067 [==============================] - 70s 66ms/step - sparse_categorical_accuracy: 0.7373 - student_loss: 0.6219 - distillation_loss: 0.0024 - val_sparse_categorical_accuracy: 0.7844 - val_student_loss: 1.0290
# Epoch 16/30
# 1067/1067 [==============================] - 71s 67ms/step - sparse_categorical_accuracy: 0.7547 - student_loss: 0.5915 - distillation_loss: 0.0023 - val_sparse_categorical_accuracy: 0.7775 - val_student_loss: 0.5807
# Epoch 17/30
# 1067/1067 [==============================] - 69s 65ms/step - sparse_categorical_accuracy: 0.7528 - student_loss: 0.5916 - distillation_loss: 0.0023 - val_sparse_categorical_accuracy: 0.8037 - val_student_loss: 0.1709
# Epoch 18/30
# 1067/1067 [==============================] - 69s 65ms/step - sparse_categorical_accuracy: 0.7784 - student_loss: 0.5525 - distillation_loss: 0.0022 - val_sparse_categorical_accuracy: 0.8062 - val_student_loss: 0.1586
# Epoch 19/30
# 1067/1067 [==============================] - 67s 63ms/step - sparse_categorical_accuracy: 0.7705 - student_loss: 0.5510 - distillation_loss: 0.0022 - val_sparse_categorical_accuracy: 0.8069 - val_student_loss: 0.4485
# Epoch 20/30
# 1067/1067 [==============================] - 71s 66ms/step - sparse_categorical_accuracy: 0.7881 - student_loss: 0.5187 - distillation_loss: 0.0021 - val_sparse_categorical_accuracy: 0.8400 - val_student_loss: 0.1924
# Epoch 21/30
# 1067/1067 [==============================] - 70s 65ms/step - sparse_categorical_accuracy: 0.7966 - student_loss: 0.4996 - distillation_loss: 0.0020 - val_sparse_categorical_accuracy: 0.8081 - val_student_loss: 0.5073
# Epoch 22/30
# 1067/1067 [==============================] - 70s 65ms/step - sparse_categorical_accuracy: 0.7970 - student_loss: 0.4877 - distillation_loss: 0.0020 - val_sparse_categorical_accuracy: 0.8081 - val_student_loss: 0.2016
# Epoch 23/30
# 1067/1067 [==============================] - 70s 65ms/step - sparse_categorical_accuracy: 0.8011 - student_loss: 0.4783 - distillation_loss: 0.0020 - val_sparse_categorical_accuracy: 0.8400 - val_student_loss: 0.4591
# Epoch 24/30
# 1067/1067 [==============================] - 66s 62ms/step - sparse_categorical_accuracy: 0.8138 - student_loss: 0.4611 - distillation_loss: 0.0019 - val_sparse_categorical_accuracy: 0.7987 - val_student_loss: 0.2176
# Epoch 25/30
# 1067/1067 [==============================] - 67s 63ms/step - sparse_categorical_accuracy: 0.8136 - student_loss: 0.4489 - distillation_loss: 0.0020 - val_sparse_categorical_accuracy: 0.8075 - val_student_loss: 0.1718
# Epoch 26/30
# 1067/1067 [==============================] - 68s 64ms/step - sparse_categorical_accuracy: 0.8284 - student_loss: 0.4315 - distillation_loss: 0.0019 - val_sparse_categorical_accuracy: 0.8438 - val_student_loss: 0.1407
# Epoch 27/30
# 1067/1067 [==============================] - 71s 66ms/step - sparse_categorical_accuracy: 0.8306 - student_loss: 0.4127 - distillation_loss: 0.0018 - val_sparse_categorical_accuracy: 0.8175 - val_student_loss: 0.2099
# Epoch 28/30
# 1067/1067 [==============================] - 69s 65ms/step - sparse_categorical_accuracy: 0.8231 - student_loss: 0.4348 - distillation_loss: 0.0019 - val_sparse_categorical_accuracy: 0.8225 - val_student_loss: 0.0860
# Epoch 29/30
# 1067/1067 [==============================] - 68s 63ms/step - sparse_categorical_accuracy: 0.8406 - student_loss: 0.3937 - distillation_loss: 0.0018 - val_sparse_categorical_accuracy: 0.8500 - val_student_loss: 0.4783
# Epoch 30/30
# 1067/1067 [==============================] - 70s 66ms/step - sparse_categorical_accuracy: 0.8420 - student_loss: 0.3890 - distillation_loss: 0.0018 - val_sparse_categorical_accuracy: 0.7487 - val_student_loss: 0.3943

# %% [markdown]
# ### <font color = red> Evaluation: Distiller Student Model </font>

# %%
# Evaluate student on test dataset
distiller_score = distiller.evaluate(X_test, y_test, verbose=0)
print(distiller_score)
# Out:
# [0.7544999718666077, 0.36490368843078613]

# %%
student_score = student.evaluate(X_test, y_test, verbose=0)
print(student_score)
# Out:
# [0.6281920671463013, 0.7544999718666077]

# %% [markdown]
# ## <font color = navy> Train Original Student Model </font>

# %%
# Train student as doen usually
student_scratch.compile(
    optimizer=keras.optimizers.Adam(),
    loss=Config.student_loss_func,
    metrics=[keras.metrics.SparseCategoricalAccuracy()])

# %%
# Train and evaluate student trained from scratch.
student_scratch_history = student_scratch.fit(
    X_train, y_train,
    validation_split=0.2,
    batch_size=Config.BATCH_SIZE,
    verbose=1,
    epochs=Config.num_epochs)
# Out:
# Epoch 1/30
# 1067/1067 [==============================] - 56s 48ms/step - loss: 4.3350 - sparse_categorical_accuracy: 0.0131 - val_loss: 4.4808 - val_sparse_categorical_accuracy: 0.0181
# Epoch 2/30
# 1067/1067 [==============================] - 53s 49ms/step - loss: 3.7172 - sparse_categorical_accuracy: 0.0572 - val_loss: 3.7425 - val_sparse_categorical_accuracy: 0.0319
# Epoch 3/30
# 1067/1067 [==============================] - 51s 48ms/step - loss: 2.7000 - sparse_categorical_accuracy: 0.1386 - val_loss: 2.1173 - val_sparse_categorical_accuracy: 0.2163
# Epoch 4/30
# 1067/1067 [==============================] - 51s 48ms/step - loss: 2.1100 - sparse_categorical_accuracy: 0.2498 - val_loss: 1.6170 - val_sparse_categorical_accuracy: 0.3669
# Epoch 5/30
# 1067/1067 [==============================] - 50s 47ms/step - loss: 1.6150 - sparse_categorical_accuracy: 0.3858 - val_loss: 1.1979 - val_sparse_categorical_accuracy: 0.4869
# Epoch 6/30
# 1067/1067 [==============================] - 52s 49ms/step - loss: 1.2634 - sparse_categorical_accuracy: 0.4891 - val_loss: 0.9482 - val_sparse_categorical_accuracy: 0.5656
# Epoch 7/30
# 1067/1067 [==============================] - 51s 48ms/step - loss: 1.0687 - sparse_categorical_accuracy: 0.5467 - val_loss: 0.7649 - val_sparse_categorical_accuracy: 0.6844
# Epoch 8/30
# 1067/1067 [==============================] - 50s 47ms/step - loss: 0.9876 - sparse_categorical_accuracy: 0.5800 - val_loss: 0.7285 - val_sparse_categorical_accuracy: 0.6988
# Epoch 9/30
# 1067/1067 [==============================] - 49s 46ms/step - loss: 0.8923 - sparse_categorical_accuracy: 0.6120 - val_loss: 0.6977 - val_sparse_categorical_accuracy: 0.7231
# Epoch 10/30
# 1067/1067 [==============================] - 51s 47ms/step - loss: 0.8464 - sparse_categorical_accuracy: 0.6330 - val_loss: 0.6839 - val_sparse_categorical_accuracy: 0.7000
# Epoch 11/30
# 1067/1067 [==============================] - 51s 48ms/step - loss: 0.7867 - sparse_categorical_accuracy: 0.6614 - val_loss: 0.6571 - val_sparse_categorical_accuracy: 0.7088
# Epoch 12/30
# 1067/1067 [==============================] - 51s 48ms/step - loss: 0.7421 - sparse_categorical_accuracy: 0.6817 - val_loss: 0.6100 - val_sparse_categorical_accuracy: 0.7369
# Epoch 13/30
# 1067/1067 [==============================] - 51s 48ms/step - loss: 0.7166 - sparse_categorical_accuracy: 0.6914 - val_loss: 0.5913 - val_sparse_categorical_accuracy: 0.7381
# Epoch 14/30
# 1067/1067 [==============================] - 51s 48ms/step - loss: 0.6836 - sparse_categorical_accuracy: 0.7106 - val_loss: 0.6567 - val_sparse_categorical_accuracy: 0.7206
# Epoch 15/30
# 1067/1067 [==============================] - 51s 48ms/step - loss: 0.6575 - sparse_categorical_accuracy: 0.7178 - val_loss: 0.4839 - val_sparse_categorical_accuracy: 0.7919
# Epoch 16/30
# 1067/1067 [==============================] - 49s 46ms/step - loss: 0.6263 - sparse_categorical_accuracy: 0.7414 - val_loss: 0.5445 - val_sparse_categorical_accuracy: 0.7644
# Epoch 17/30
# 1067/1067 [==============================] - 50s 47ms/step - loss: 0.6131 - sparse_categorical_accuracy: 0.7402 - val_loss: 0.4533 - val_sparse_categorical_accuracy: 0.8019
# Epoch 18/30
# 1067/1067 [==============================] - 50s 47ms/step - loss: 0.5929 - sparse_categorical_accuracy: 0.7484 - val_loss: 0.4826 - val_sparse_categorical_accuracy: 0.7900
# Epoch 19/30
# 1067/1067 [==============================] - 51s 48ms/step - loss: 0.5939 - sparse_categorical_accuracy: 0.7520 - val_loss: 0.6634 - val_sparse_categorical_accuracy: 0.7081
# Epoch 20/30
# 1067/1067 [==============================] - 51s 48ms/step - loss: 0.5482 - sparse_categorical_accuracy: 0.7747 - val_loss: 0.4681 - val_sparse_categorical_accuracy: 0.8094
# Epoch 21/30
# 1067/1067 [==============================] - 51s 48ms/step - loss: 0.5309 - sparse_categorical_accuracy: 0.7773 - val_loss: 0.5060 - val_sparse_categorical_accuracy: 0.7900
# Epoch 22/30
# 1067/1067 [==============================] - 50s 47ms/step - loss: 0.5108 - sparse_categorical_accuracy: 0.7933 - val_loss: 0.4484 - val_sparse_categorical_accuracy: 0.8081
# Epoch 23/30
# 1067/1067 [==============================] - 50s 47ms/step - loss: 0.5195 - sparse_categorical_accuracy: 0.7819 - val_loss: 0.4560 - val_sparse_categorical_accuracy: 0.8025
# Epoch 24/30
# 1067/1067 [==============================] - 51s 48ms/step - loss: 0.4911 - sparse_categorical_accuracy: 0.7945 - val_loss: 0.4829 - val_sparse_categorical_accuracy: 0.8012
# Epoch 25/30
# 1067/1067 [==============================] - 51s 48ms/step - loss: 0.4662 - sparse_categorical_accuracy: 0.8094 - val_loss: 0.6124 - val_sparse_categorical_accuracy: 0.7331
# Epoch 26/30
# 1067/1067 [==============================] - 51s 48ms/step - loss: 0.4789 - sparse_categorical_accuracy: 0.8020 - val_loss: 0.4123 - val_sparse_categorical_accuracy: 0.8150
# Epoch 27/30
# 1067/1067 [==============================] - 51s 48ms/step - loss: 0.4584 - sparse_categorical_accuracy: 0.8122 - val_loss: 0.3762 - val_sparse_categorical_accuracy: 0.8275
# Epoch 28/30
# 1067/1067 [==============================] - 51s 48ms/step - loss: 0.4373 - sparse_categorical_accuracy: 0.8184 - val_loss: 0.4538 - val_sparse_categorical_accuracy: 0.8081
# Epoch 29/30
# 1067/1067 [==============================] - 51s 48ms/step - loss: 0.4303 - sparse_categorical_accuracy: 0.8220 - val_loss: 0.5105 - val_sparse_categorical_accuracy: 0.7950
# Epoch 30/30
# 1067/1067 [==============================] - 51s 48ms/step - loss: 0.4229 - sparse_categorical_accuracy: 0.8258 - val_loss: 0.3907 - val_sparse_categorical_accuracy: 0.8288

# %% [markdown]
# ### <font color = red> Evaluation: Original Student Model </font>

# %%
student_scratch_score = student_scratch.evaluate(X_test, y_test, verbose=0)
print(student_scratch_score)
# Out:
# [0.3783220052719116, 0.8335000276565552]

# %% [markdown]
# ## <font color = navy> Save & Load Teacher model </font>

# %%
teacher.save('teacher')
# Out:
# /home/bakerchen/.conda/envs/2023ARC/lib/python3.8/site-packages/tensorflow/python/keras/utils/generic_utils.py:494: CustomMaskWarning: Custom mask layers require a config and must override get_config. When loading, the custom mask layer must be passed to the custom_objects argument.
#   warnings.warn('Custom mask layers require a config and must override '
# INFO:tensorflow:Assets written to: teacher/assets

# %%
teacher = keras.models.load_model("teacher")

# %% [markdown]
# ## <font color = navy> Proposed Method: Model Fractionation </font>

# %%
# def fractionizer(models, stages):
#     for i in range(len(models)):
#         print('Stage ', i)
